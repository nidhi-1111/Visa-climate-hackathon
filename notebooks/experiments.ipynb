# %%
import pandas as pd

# %%
card_file_path = "D:\\Curious\\Visa-climate-hackathon\\data\\card_data.csv"
bank_file_path = "D:\\Curious\\Visa-climate-hackathon\\data\\open_bank_data.csv"

card_data = pd.read_csv(card_file_path)
bank_data = pd.read_csv(bank_file_path)

# %%
card_data.describe()
# Out:
#          cpd_mnth_id  mrch_catg_cd      cp_flag  domestic_flag  \
# count    1379.000000   1379.000000  1379.000000    1379.000000
# mean   202306.042785   5927.504714     0.627266       0.960841
# std         0.814632    917.188181     0.483708       0.194043
# min    202305.000000   4111.000000     0.000000       0.000000
# 25%    202305.000000   5411.000000     0.000000       1.000000
# 50%    202306.000000   5812.000000     1.000000       1.000000
# 75%    202307.000000   5994.000000     1.000000       1.000000
# max    202307.000000   9402.000000     1.000000       1.000000
#
#        intraregion_flag  interregion_flag  country_code        spend
# count       1379.000000       1379.000000   1379.000000  1379.000000
# mean           0.023930          0.015228    812.819434    28.885417
# std            0.152888          0.122505     79.476069    36.170459
# min            0.000000          0.000000    124.000000     0.150000
# ...

# %%
bank_data.describe()
# Out:
#             amount
# count  1378.000000
# mean     28.868186
# std      36.177928
# min       0.150000
# 25%       7.220000
# 50%      15.615000
# 75%      34.485000
# max     299.980000

# %%
"Clusters are same in both the dataset"
card_data['cluster_name_adjusted'].unique()
# Out:
# array(['Family', 'Affluent Segment', 'Frugal Family', 'Urban Spenders',
#        'Sensible Spenders'], dtype=object)

# %%
"This shows from which merchant users purchased - amazon, asos.com, airbnb, cafe nero etc"
card_data['merchant'].nunique()
# Out:
# 337

# %%
"This column shows where users are spending such as grocery stores, sports, parking, tarvel etc"
card_data['mrch_catg_rlup_nm'].nunique()
# Out:
# 80

# %%
card_data['merchant'].groupby()
# Out:
#       cpd_mnth_id     cpd_dt cluster_name_adjusted  mrch_catg_cd  \
# 0          202306   6/8/2023                Family          7523
# 1          202306  6/13/2023      Affluent Segment          5499
# 2          202307   7/9/2023      Affluent Segment          5499
# 3          202306  6/13/2023      Affluent Segment          5499
# 4          202307   7/9/2023      Affluent Segment          5499
# ...           ...        ...                   ...           ...
# 1374       202306  6/24/2023        Urban Spenders          5999
# 1375       202307   7/3/2023        Urban Spenders          5999
# 1376       202306  6/30/2023        Urban Spenders          7922
# 1377       202305  5/18/2023      Affluent Segment          7523
# 1378       202306  6/12/2023         Frugal Family          7523
#
#                 mrch_catg_rlup_nm        merchant  cp_flag  domestic_flag  \
# 0     PARKING LOTS,METERS,GARAGES           APCOA        0              1
# ...

# %%
"Clusters are same in both the dataset"
bank_data['cluster_name_adjusted'].unique()
# Out:
# array(['Affluent Segment', 'Urban Spenders', 'Frugal Family', 'Family',
#        'Sensible Spenders'], dtype=object)
